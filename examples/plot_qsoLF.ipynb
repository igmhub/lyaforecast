# %% [markdown]
# # Plot Quasar LF

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import qso_LF as qLF
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# create QLF object
LF = qLF.QuasarLF()
mmin,mmax = LF.range_mag()
#zmin,zmax = LF.QL_range_z()
m = np.linspace(mmin,mmax,100)
# Out:
# z (24,)
# m (14,)
# dN (24, 14)

# %%
# make plots at several z
plt.semilogy(m,LF.dNdzdmddeg2(2.0,m)[0],label='z=2.0')
plt.semilogy(m,LF.dNdzdmddeg2(2.5,m)[0],label='z=2.5')
plt.semilogy(m,LF.dNdzdmddeg2(3.0,m)[0],label='z=3.0')
plt.semilogy(m,LF.dNdzdmddeg2(3.5,m)[0],label='z=3.5')
plt.semilogy(m,LF.dNdzdmddeg2(4.0,m)[0],label='z=4.0')
plt.semilogy(m,LF.dNdzdmddeg2(4.5,m)[0],label='z=4.5')
plt.semilogy(m,LF.dNdzdmddeg2(5.0,m)[0],label='z=5.0')
plt.legend(loc=2,fontsize=15)
plt.ylim(1e-2,1e2)
plt.xlim(mmin,mmax)
plt.xlabel('g mag',fontsize=15)
plt.ylabel(r'dN / dz / dmag / $\rm{ddeg}^2$',fontsize=15)
plt.show()

# %%
print('2.1 22.75',LF.dNdzdmddeg2(2.1,22.75))
print('2.1 22.50',LF.dNdzdmddeg2(2.1,22.5))
print('2.10522, 23',LF.dNdzdmddeg2(2.10522,23))
# Out:
# 2.1 22.75 [[ 18.2808]]
# 2.1 22.50 [[ 24.25928882]]
# 2.10522, 23 [[ 9.34314707]]

# %%
print('2.1,m',LF.dNdzdmddeg2(2.1,m))
# Out:
# 2.1,m [[  4.62422901e-03   4.29996088e-03   4.31081744e-03   4.65679868e-03
#     5.33790461e-03   6.35413522e-03   7.70549051e-03   9.39197049e-03
#     1.14135752e-02   1.37703045e-02   1.64621585e-02   1.94891372e-02
#     2.28512406e-02   2.65484687e-02   3.05808215e-02   3.52804675e-02
#     4.12102480e-02   4.83793899e-02   5.67878931e-02   6.64357577e-02
#     7.73229837e-02   8.94495711e-02   1.03477133e-01   1.20838253e-01
#     1.41582141e-01   1.65708799e-01   1.93218226e-01   2.24110421e-01
#     2.58385385e-01   2.97612834e-01   3.46125183e-01   4.04173587e-01
#     4.71758045e-01   5.48878557e-01   6.35535124e-01   7.31727746e-01
#     8.39811152e-01   9.68099574e-01   1.11731978e+00   1.28747177e+00
#     1.47855555e+00   1.69057111e+00   1.92351845e+00   2.17949486e+00
#     2.46806915e+00   2.79042104e+00   3.14655054e+00   3.53645764e+00
#     3.96014234e+00   4.41760464e+00   4.90791068e+00   5.42545729e+00
#     5.96931059e+00   6.53947060e+00   7.13593731e+00   7.75871073e+00
#     8.40779084e+00   9.08127268e+00   9.76370481e+00   1.04517006e+01
#     1.11452601e+01   1.18443832e+01   1.25490700e+01   1.32593205e+01
#     1.39743781e+01   1.46855879e+01   1.53904988e+01   1.60891107e+01
#     1.67814237e+01   1.74674377e+01   1.81471528e+01   1.88214042e+01
#     1.95046025e+01   2.02019687e+01   2.09135027e+01   2.16392047e+01
#     2.23790746e+01   2.31331124e+01   2.38995608e+01   2.46272615e+01
#     2.52925880e+01   2.58955404e+01   2.64361187e+01   2.69143227e+01
#     2.73301526e+01   2.76819106e+01   2.78660306e+01   2.78213917e+01
#     2.75479940e+01   2.70458374e+01   2.63149219e+01   2.53552476e+01
#     2.41668143e+01   2.27496223e+01   2.11036713e+01   1.92289615e+01
#     1.71254928e+01   1.47932653e+01   1.22322788e+01   9.44253355e+00]]
