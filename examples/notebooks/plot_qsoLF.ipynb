# %% [markdown]
# # Tracer redshift and magnitude distributions
#
# These are r-band density distributions from the current Tracer loader, with the configured target density normalization. The obsolete g-band comparison has been removed.
#
# Install with `python -m pip install -e ".[plot,notebook]"`. Run this notebook from `examples/notebooks`. Set `LYAFORECAST_EXAMPLE_CONFIG` to choose another authoritative INI. Figures and logs go to a temporary directory, never packaged resources. These development workloads run on login nodes.

# %%
import os
import sys
import tempfile
from pathlib import Path

import matplotlib.pyplot as plt

sys.path.insert(0, str(Path("../scripts").resolve()))
from _diagnostics import DEFAULT_CONFIG, load_forecast, style, PLOTS

style()
config_path = Path(os.environ.get("LYAFORECAST_EXAMPLE_CONFIG", DEFAULT_CONFIG))
output = tempfile.TemporaryDirectory(prefix="lyaforecast-example-")
forecast = load_forecast(config_path, output.name)
# Out:
# INFO - Running BAO forecast
# INFO - Tracers: ['lya(qso)', 'qso']
# INFO - Correlations: ['lya(qso)_lya(qso)', 'lya(qso)_qso', 'qso_qso']
# Initialise forecast
# Enforcing m>=16.1
# Enforcing m<=26.75
# Scaling lya dndzdm from a total density (z>=2.15) of 3789.6 to 90.0/deg2
# Scaling dndzdm tracer from a total density of 3789.6134994140098 to 90.0/deg2
# Setting up DESI spectrograph
# WARNING: maximum brightness capped at magnitude 19.25
# In S/N files:
# pass-band for magnitudes = r
# Nexp in file             = 4
# Redshifts                = [2.   2.25 2.5  2.75 3.   3.25 3.5  3.75 4.   4.25 4.5  4.75]
# Magnitudes               = [19.25 19.75 20.25 20.75 21.25 21.75 22.25 22.75 23.25 23.75 24.25 24.75]
# reading magnitude 19.25 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r19.25-t4000-nexp4.dat
# reading magnitude 19.75 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r19.75-t4000-nexp4.dat
# reading magnitude 20.25 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r20.25-t4000-nexp4.dat
# reading magnitude 20.75 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r20.75-t4000-nexp4.dat
# reading magnitude 21.25 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r21.25-t4000-nexp4.dat
# reading magnitude 21.75 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r21.75-t4000-nexp4.dat
# reading magnitude 22.25 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r22.25-t4000-nexp4.dat
# reading magnitude 22.75 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r22.75-t4000-nexp4.dat
# reading magnitude 23.25 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r23.25-t4000-nexp4.dat
# reading magnitude 23.75 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r23.75-t4000-nexp4.dat
# reading magnitude 24.25 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r24.25-t4000-nexp4.dat
# reading magnitude 24.75 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r24.75-t4000-nexp4.dat
# Setting up DESI spectrograph
# WARNING: maximum brightness capped at magnitude 19.25
# In S/N files:
# pass-band for magnitudes = r
# Nexp in file             = 4
# Redshifts                = [2.   2.25 2.5  2.75 3.   3.25 3.5  3.75 4.   4.25 4.5  4.75]
# Magnitudes               = [19.25 19.75 20.25 20.75 21.25 21.75 22.25 22.75 23.25 23.75 24.25 24.75]
# reading magnitude 19.25 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r19.25-t4000-nexp4.dat
# reading magnitude 19.75 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r19.75-t4000-nexp4.dat
# reading magnitude 20.25 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r20.25-t4000-nexp4.dat
# reading magnitude 20.75 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r20.75-t4000-nexp4.dat
# reading magnitude 21.25 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r21.25-t4000-nexp4.dat
# reading magnitude 21.75 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r21.75-t4000-nexp4.dat
# reading magnitude 22.25 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r22.25-t4000-nexp4.dat
# reading magnitude 22.75 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r22.75-t4000-nexp4.dat
# reading magnitude 23.25 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r23.25-t4000-nexp4.dat
# reading magnitude 23.75 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r23.75-t4000-nexp4.dat
# reading magnitude 24.25 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r24.25-t4000-nexp4.dat
# reading magnitude 24.75 in file /global/cfs/cdirs/desicollab/users/acuceu/vega_dev/lib/lyaforecast/lyaforecast/resources/data/DESI-2-QSO/snr-r24.75-t4000-nexp4.dat
# No bias function provided for lya(qso)
# No bias function provided for qso

# %%
figures = PLOTS["density"](forecast)
plt.show()

# %% [markdown]
# The matching script shares the plotting functions above; scientific calculations remain in the package. To export a figure, call `figure.savefig(...)` with your chosen destination.
